# %% [markdown]
# # Data Keystone: Exploring the Dataset

# %% [markdown]
# ## Loading the Dataset

# %%
import pandas as pd

df = pd.read_csv('steam_games_dataset.csv')

# %% [markdown]
# ## Exploring the Dataset Structure

# %%
print(df.head())
print(df.info())
print(df.shape)
df.columns
df.dtypes
# Out:
#      appid                              name         developer  \
# 0      730  Counter-Strike: Global Offensive             Valve
# 1  1172470                      Apex Legends           Respawn
# 2   578080               PUBG: BATTLEGROUNDS  PUBG Corporation
# 3  1623730                          Palworld        Pocketpair
# 4      440                   Team Fortress 2             Valve
#
#          publisher  score_rank  positive  negative  userscore  \
# 0            Valve         NaN   7642084   1173003          0
# 1  Electronic Arts         NaN    668053    326926          0
# 2    KRAFTON, Inc.         NaN   1520457   1037487          0
# 3       Pocketpair         NaN    358266     22443          0
# 4            Valve         NaN   1044264    117208          0
#
#                        owners  average_forever  average_2weeks  \
# 0  100,000,000 .. 200,000,000            33852             708
# 1  100,000,000 .. 200,000,000            10506             496
# ...

# %% [markdown]
# ## Exploring Column Values

# %%
print(df.value_counts())
print(df.describe())
# Out:
# appid   name                            developer                 publisher                score_rank  positive  negative  userscore  owners                average_forever  average_2weeks  median_forever  median_2weeks  price  initialprice  discount  ccu
# 22490   Fallout: New Vegas              Obsidian Entertainment    Bethesda Softworks       100.0       46753     2153      95         500,000 .. 1,000,000  3333             379             1409            310            999    999           0         318    1
# 790650  MARVEL END TIME ARENA           Smilegate Entertainment   Smilegate Entertainment  99.0        368       160       69         100,000 .. 200,000    158              0               158             0              0      0             0         0      1
# ...

# %% [markdown]
# The values of the 'appid' column are in exponential notation, which provides little value on its own. Steam is a massive platform, but surely the ids can't be that large.

# %%
df['appid'].max()
# Out:
# np.int64(3605460)

# %% [markdown]
# The maximum value from the 'appid' column is on 7 digits long, but it is stored as an int64. That feels excessive.

# %%
df = df.astype({'appid': 'int32'})
print(df.dtypes)
# Out:
# appid                int32
# name                   str
# developer              str
# publisher              str
# score_rank         float64
# positive             int64
# negative             int64
# userscore            int64
# owners                 str
# average_forever      int64
# average_2weeks       int64
# median_forever       int64
# median_2weeks        int64
# price                int64
# initialprice         int64
# discount             int64
# ccu                  int64
# dtype: object

# %%
df.head()
df.describe()
# Out:
#               appid  score_rank      positive      negative     userscore  \
# count  1.000000e+04         5.0  1.000000e+04  1.000000e+04  10000.000000
# mean   9.008700e+05        99.0  1.214202e+04  1.948096e+03      0.036000
# std    7.290494e+05         1.0  9.536926e+04  1.812977e+04      1.671581
# min    1.000000e+01        98.0  0.000000e+00  0.000000e+00      0.000000
# 25%    3.365875e+05        98.0  4.310000e+02  1.100000e+02      0.000000
# 50%    6.551300e+05        99.0  1.514500e+03  2.950000e+02      0.000000
# 75%    1.333238e+06       100.0  4.996750e+03  8.712500e+02      0.000000
# max    3.605460e+06       100.0  7.642084e+06  1.173003e+06     95.000000
#
#        average_forever  average_2weeks  median_forever  median_2weeks  \
# count     10000.000000    10000.000000    10000.000000   10000.000000
# mean       1023.689500      112.496300      515.001700     118.949000
# std        4193.287962      638.473189     3508.429257     707.962801
# ...

# %% [markdown]
# Okay, changing the dtype didn't fix the notation issue... Online research suggests the only way to adjust it is to change a global pandas setting for trailing zeros on a float. Not ideal, so we'll let the describe nuance go. That being said, more of these column dtypes likely don't need int64. Let's adjust those further.

# %%
# Convert dtypes from int64 to smaller increments here

# %% [markdown]
# ## Practicing Basic Cleaning and Wrangling

# %%
df[df['score_rank'] == 100.0]
# Out:
#        appid                            name               developer  \
# 2122   22490              Fallout: New Vegas  Obsidian Entertainment
# 9662  639780  Deep Space Waifu: FLAT JUSTICE     Neko Climax Studios
#
#                 publisher  score_rank  positive  negative  userscore  \
# 2122   Bethesda Softworks       100.0     46753      2153         95
# 9662  Neko Climax Studios       100.0      1449        67         95
#
#                     owners  average_forever  average_2weeks  median_forever  \
# 2122  500,000 .. 1,000,000             3333             379            1409
# 9662     50,000 .. 100,000              137               0             111
#
#       median_2weeks  price  initialprice  discount  ccu
# 2122            310    999           999         0  318
# 9662              0    399           399         0    0
